# %%
# %%time
import pandas as pd
from sklearn.metrics import f1_score, classification_report

test_df = pd.read_csv('test.csv');
train_df = pd.read_csv('train.csv');
# Out:
# CPU times: total: 1.38 s
# Wall time: 1.49 s

# %%
train_df['y'] = train_df['y'].map({'yes': 1, 'no': 0})
submission = pd.DataFrame({
    'id': test_df['id'],
    'y': [0] * len(test_df)
})

submission.to_csv('submission.csv', index=False)
print("Submission file created")
print(submission.head())

try:
    solution_df = pd.read_csv('C:/Users/arfas/OneDrive/Desktop/VSCODEZ/Codez-Py/solution.csv')
    
    y_true = solution_df['y']
    y_pred = submission['y']
    
    f1 = f1_score(y_true, y_pred)
    
    print("\n" + "="*50)
    print("EVALUATION RESULT")
    print("="*50)
    print(f"F1-Score: {f1:.4f}")
    print("\nClassification Report:")
    print(classification_report(y_true, y_pred))
    
except FileNotFoundError:
    print("\nFile solution.csv tidak ditemukan. Skip evaluasi.")

input("\nPress Enter to exit...")
# Out:
# Submission file created
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 9
#       7 submission.to_csv('submission.csv', index=False)
#       8 print("Submission file created")
# ----> 9 input("Ketik 1")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py:1473, in Kernel.raw_input(self, prompt)
#    1471     msg = "raw_input was called, but this frontend does not support input requests."
#    1472     raise StdinNotImplementedError(msg)
# -> 1473 return self._input_request(
#    1474     str(prompt),
#    1475     self._shell_parent_ident.get(),
#    1476     self.get_parent("shell"),
#    1477     password=False,
#    1478 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py:1518, in Kernel._input_request(self, prompt, ident, parent, password)
#    1515 except KeyboardInterrupt:
#    1516     # re-raise KeyboardInterrupt, to truncate traceback
#    1517     msg = "Interrupted by user"
# -> 1518     raise KeyboardInterrupt(msg) from None
#    1519 except Exception:
#    1520     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
