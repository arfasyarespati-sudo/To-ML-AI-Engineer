# %%
import pandas as pd
import numpy as np
from scipy import stats

# Membaca data
df = pd.read_csv('vgsales.csv') # Sesuaikan dengan nama filemu

# Kita akan menggunakan kolom 'Global_Sales' sebagai contoh perhitungan
data = df['Global_Sales'].dropna()
